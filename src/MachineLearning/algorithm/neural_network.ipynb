# %% [markdown]
# # NEURAL NETWORK IN PYLAB
# Back Propgation Example

# %%
from pylab import *

# %%
run LDA.py
# Out:
# train err: 0.091796875
# test err: 0.140350877193

# %%
# load dataset
from sklearn.datasets import load_boston
dataset = load_boston()
X, Y = dataset['data'], dataset['target']
